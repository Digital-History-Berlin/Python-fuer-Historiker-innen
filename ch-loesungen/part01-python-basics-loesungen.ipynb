# %% [markdown]
# # Lösungen zu den Aufgaben aus Python Basics
#
# :::{note}
# Bei den Lösungen handelt es sich um Vorschläge.
#
# Es gibt nicht einen einzigen richtigen Lösungsweg.
# :::
